# %%
import pandas as pd

# %%
df = pd.read_csv("hello 2.csv")
df
# Out:
#        Unnamed: 0  Playtime  Feedback  \
# 0               0        16  Positive
# 1               1        26  Positive
# 2               2        29  Positive
# 3               3        24  Positive
# 4               4         7  Positive
# ...           ...       ...       ...
# 46400       46400         4  Positive
# 46401       46401        11  Positive
# 46402       46402         8  Positive
# 46403       46403         1  Positive
# 46404       46404         6  Positive
#
#                                                   Review
# 0                                          Greattt Game!
# 1      9/10Fantastic experience. A true Wizarding Wor...
# 2                                               worth it
# 3      I've been waiting 84 YEARSSSSSSSS.The game is ...
# 4           very fun game (it is not transphobic at all)
# ...                                                  ...
# 46400                      Justice for Voldemort's nose!
# ...

# %%
review = df.loc[30, "Review"]
print(review)
# Out:
# Hogwarts Legacy is a very mediocre, generic and formulaic modern open world game that's saved from being a bad game by the Harry Potter license. They've done a good job of recreating Hogwarts and it is honestly really cool being able to fly around and above the castle on your broom seamlessly. I had fun in my first several hours playing the game just exploring the castle and the areas outside around the castle like hogsmeade. The more you progress though the more you realise how little the game has to offer. One of the biggest offenders is how lifeless the world feels with the lack of interaction in general. I compare it to Bully which came out 17 years ago now. When you walk around the school in Bully it feels like you are a part of that world. There is a time mechanic where you need to get to class on time and go to bed on time etc. All the NPC's have their routine they're following making you feel like the world is moving regardless of you being there rather than it feeling like t
# ...

# %%
review.split(".")
# Out:
# ["Hogwarts Legacy is a very mediocre, generic and formulaic modern open world game that's saved from being a bad game by the Harry Potter license",
#  " They've done a good job of recreating Hogwarts and it is honestly really cool being able to fly around and above the castle on your broom seamlessly",
#  ' I had fun in my first several hours playing the game just exploring the castle and the areas outside around the castle like hogsmeade',
#  ' The more you progress though the more you realise how little the game has to offer',
#  ' One of the biggest offenders is how lifeless the world feels with the lack of interaction in general',
#  ' I compare it to Bully which came out 17 years ago now',
#  ' When you walk around the school in Bully it feels like you are a part of that world',
#  ' There is a time mechanic where you need to get to class on time and go to bed on time etc',
# ...

# %%
#pip install  gensim
import gensim
from gensim.utils import tokenize

# %%
list(tokenize(review))
# Out:
# ['Hogwarts',
#  'Legacy',
#  'is',
#  'a',
#  'very',
#  'mediocre',
#  'generic',
#  'and',
#  'formulaic',
#  'modern',
#  'open',
#  'world',
#  'game',
#  'that',
#  's',
#  'saved',
#  'from',
#  'being',
#  'a',
#  'bad',
#  'game',
#  'by',
#  'the',
#  'Harry',
#  'Potter',
#  'license',
#  'They',
#  've',
#  'done',
#  'a',
#  'good',
#  'job',
#  'of',
#  'recreating',
#  'Hogwarts',
#  'and',
#  'it',
#  'is',
#  'honestly',
#  'really',
#  'cool',
#  'being',
#  'able',
#  'to',
#  'fly',
#  'around',
#  'and',
#  'above',
#  'the',
#  'castle',
#  'on',
#  'your',
#  'broom',
#  'seamlessly',
#  'I',
#  'had',
#  'fun',
#  'in',
#  'my',
#  'first',
#  'several',
#  'hours',
#  'playing',
#  'the',
#  'game',
#  'just',
#  'exploring',
#  'the',
#  'castle',
#  'and',
#  'the',
#  'areas',
#  'outside',
#  'around',
#  'the',
#  'castle',
#  'like',
#  'hogsmeade',
#  'The',
#  'more',
#  'you',
#  'progress',
#  'though',
#  'the',
#  'more',
#  'you',
#  'realise',
# ...

# %%
len(review.split())
# Out:
# 536

# %%
len(review)
# Out:
# 2904

# %%
#by regex
import re

# %%
re.split(r"(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?|!)\s", review)
# Out:
# ["Hogwarts Legacy is a very mediocre, generic and formulaic modern open world game that's saved from being a bad game by the Harry Potter license.",
#  "They've done a good job of recreating Hogwarts and it is honestly really cool being able to fly around and above the castle on your broom seamlessly.",
#  'I had fun in my first several hours playing the game just exploring the castle and the areas outside around the castle like hogsmeade.',
#  'The more you progress though the more you realise how little the game has to offer.',
#  'One of the biggest offenders is how lifeless the world feels with the lack of interaction in general.',
#  'I compare it to Bully which came out 17 years ago now.',
#  'When you walk around the school in Bully it feels like you are a part of that world.',
#  'There is a time mechanic where you need to get to class on time and go to bed on time etc.',
# ...

# %%
from nltk.tokenize import regexp_tokenize
regexp_tokenize(review,"[\w']+")
# Out:
# ['Hogwarts',
#  'Legacy',
#  'is',
#  'a',
#  'very',
#  'mediocre',
#  'generic',
#  'and',
#  'formulaic',
#  'modern',
#  'open',
#  'world',
#  'game',
#  "that's",
#  'saved',
#  'from',
#  'being',
#  'a',
#  'bad',
#  'game',
#  'by',
#  'the',
#  'Harry',
#  'Potter',
#  'license',
#  "They've",
#  'done',
#  'a',
#  'good',
#  'job',
#  'of',
#  'recreating',
#  'Hogwarts',
#  'and',
#  'it',
#  'is',
#  'honestly',
#  'really',
#  'cool',
#  'being',
#  'able',
#  'to',
#  'fly',
#  'around',
#  'and',
#  'above',
#  'the',
#  'castle',
#  'on',
#  'your',
#  'broom',
#  'seamlessly',
#  'I',
#  'had',
#  'fun',
#  'in',
#  'my',
#  'first',
#  'several',
#  'hours',
#  'playing',
#  'the',
#  'game',
#  'just',
#  'exploring',
#  'the',
#  'castle',
#  'and',
#  'the',
#  'areas',
#  'outside',
#  'around',
#  'the',
#  'castle',
#  'like',
#  'hogsmeade',
#  'The',
#  'more',
#  'you',
#  'progress',
#  'though',
#  'the',
#  'more',
#  'you',
#  'realise',
#  'how',
# ...

# %%
#by spacy
import spacy
import spacy.cli
spacy.cli.download("de_core_news_sm")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('de_core_news_sm')

# %%
nlp = spacy.load('de_core_news_sm') 
nlp

# %%
[sent.text for sent in nlp(review).sents]
# Out:
# ['Hogwarts Legacy is a very mediocre, generic and formulaic modern open',
#  "world game that's saved from being a",
#  'bad game by the Harry Potter license.',
#  "They've done a good job of recreating Hogwarts and it is honestly really cool being able to fly around and above the castle on your broom seamlessly.",
#  'I had fun in my first several hours playing the game',
#  'just exploring the castle and the areas outside around the castle like hogsmeade.',
#  'The more you',
#  'progress though the more you realise',
#  'how',
#  'little',
#  'the game has to offer.',
#  'One of the biggest offenders is',
#  'how',
#  'lifeless the world feels with the lack of interaction in general.',
#  'I compare it to Bully which came out 17 years ago now.',
#  'When you',
#  'walk around the school in Bully it feels like you are a part of that world.',
#  'There is a time mechanic',
#  'where you need to get to class on time and go to bed on time',
#  'etc.',
#  "All the NPC's have their",
# ...

# %%
from spacy.tokenizer import Tokenizer
from spacy.lang.en import English
nlp = English()

# %%
tokenizer = Tokenizer(nlp.vocab)

# %%
tokens = tokenizer(review)

# %%
print("Blank tokenizer",end=" : ")
for token in tokens:
    print(token,end=', ')
# Out:
# Blank tokenizer : Hogwarts, Legacy, is, a, very, mediocre,, generic, and, formulaic, modern, open, world, game, that's, saved, from, being, a, bad, game, by, the, Harry, Potter, license., They've, done, a, good, job, of, recreating, Hogwarts, and, it, is, honestly, really, cool, being, able, to, fly, around, and, above, the, castle, on, your, broom, seamlessly., I, had, fun, in, my, first, several, hours, playing, the, game, just, exploring, the, castle, and, the, areas, outside, around, the, castle, like, hogsmeade., The, more, you, progress, though, the, more, you, realise, how, little, the, game, has, to, offer., One, of, the, biggest, offenders, is, how, lifeless, the, world, feels, with, the, lack, of, interaction, in, general., I, compare, it, to, Bully, which, came, out, 17, years, ago, now., When, you, walk, around, the, school, in, Bully, it, feels, like, you, are, a, part, of, that, world., There, is, a, time, mechanic, where, you, need, to, get, to, class, on, time, and, g
# ...

# %%
tokenizer = nlp.tokenizer
tokens = tokenizer(review)
print("\nDefault tokenizer",end=' : ')
for token in tokens:
    print(token,end=', ')
# Out:
# Default tokenizer : Hogwarts, Legacy, is, a, very, mediocre, ,, generic, and, formulaic, modern, open, world, game, that, 's, saved, from, being, a, bad, game, by, the, Harry, Potter, license, ., They, 've, done, a, good, job, of, recreating, Hogwarts, and, it, is, honestly, really, cool, being, able, to, fly, around, and, above, the, castle, on, your, broom, seamlessly, ., I, had, fun, in, my, first, several, hours, playing, the, game, just, exploring, the, castle, and, the, areas, outside, around, the, castle, like, hogsmeade, ., The, more, you, progress, though, the, more, you, realise, how, little, the, game, has, to, offer, ., One, of, the, biggest, offenders, is, how, lifeless, the, world, feels, with, the, lack, of, interaction, in, general, ., I, compare, it, to, Bully, which, came, out, 17, years, ago, now, ., When, you, walk, around, the, school, in, Bully, it, feels, like, you, are, a, part, of, that, world, ., There, is, a, time, mechanic, where, you, need, to, get, to, c
# ...

# %%
#!pip install nltk

import nltk

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Aafreen
# [nltk_data]     Pathan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize

sent_tokenize(review)
# Out:
# ["Hogwarts Legacy is a very mediocre, generic and formulaic modern open world game that's saved from being a bad game by the Harry Potter license.",
#  "They've done a good job of recreating Hogwarts and it is honestly really cool being able to fly around and above the castle on your broom seamlessly.",
#  'I had fun in my first several hours playing the game just exploring the castle and the areas outside around the castle like hogsmeade.',
#  'The more you progress though the more you realise how little the game has to offer.',
#  'One of the biggest offenders is how lifeless the world feels with the lack of interaction in general.',
#  'I compare it to Bully which came out 17 years ago now.',
#  'When you walk around the school in Bully it feels like you are a part of that world.',
#  'There is a time mechanic where you need to get to class on time and go to bed on time etc.',
# ...

# %%
from nltk.probability import FreqDist
fdist = FreqDist(review)
fdist
# Out:
# FreqDist({' ': 535, 'e': 303, 'o': 190, 't': 189, 'a': 172, 'i': 161, 's': 144, 'l': 144, 'n': 130, 'r': 117, ...})

# %%
fdist.N()
# Out:
# 2904

# %%
from nltk.tokenize import word_tokenize
print(word_tokenize(review))
# Out:
# ['Hogwarts', 'Legacy', 'is', 'a', 'very', 'mediocre', ',', 'generic', 'and', 'formulaic', 'modern', 'open', 'world', 'game', 'that', "'s", 'saved', 'from', 'being', 'a', 'bad', 'game', 'by', 'the', 'Harry', 'Potter', 'license', '.', 'They', "'ve", 'done', 'a', 'good', 'job', 'of', 'recreating', 'Hogwarts', 'and', 'it', 'is', 'honestly', 'really', 'cool', 'being', 'able', 'to', 'fly', 'around', 'and', 'above', 'the', 'castle', 'on', 'your', 'broom', 'seamlessly', '.', 'I', 'had', 'fun', 'in', 'my', 'first', 'several', 'hours', 'playing', 'the', 'game', 'just', 'exploring', 'the', 'castle', 'and', 'the', 'areas', 'outside', 'around', 'the', 'castle', 'like', 'hogsmeade', '.', 'The', 'more', 'you', 'progress', 'though', 'the', 'more', 'you', 'realise', 'how', 'little', 'the', 'game', 'has', 'to', 'offer', '.', 'One', 'of', 'the', 'biggest', 'offenders', 'is', 'how', 'lifeless', 'the', 'world', 'feels', 'with', 'the', 'lack', 'of', 'interaction', 'in', 'general', '.', 'I', 'compare', 'it
# ...
